# %%
""" Write a Python program to plot several lines with different format styles in one command using arrays. 
"""

import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0., 5., 0.2)

plt.plot(t, t, 'g--', t, t**2, 'bs', t, t**3, 'r^')
# Out:
# [<matplotlib.lines.Line2D at 0x7f74a92de978>,
#  <matplotlib.lines.Line2D at 0x7f74a92deb00>,
#  <matplotlib.lines.Line2D at 0x7f74a92dec88>]
